# %% [markdown]
# ### Menú

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import numpy as np

# %%
url = 'https://mifarma.es'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'\n<!DOCTYPE html>\n<!--[if lt IE 7 ]> <html lang="es" id="top" class="no-js ie6"> <![endif]-->\n<!--[if IE 7 ]>    <html lang="es" id="top" class="no-js ie7"> <![endif]-->\n<!--[if IE 8 ]>    <html lang="es" id="top" class="no-js ie8"> <![endif]-->\n<!--[if IE 9 ]>    <html lang="es" id="top" class="no-js ie9"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html lang="es" id="top" class="no-js"> <!--<![endif]-->\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<title>Tu Farmacia Online y Parafarmacia de Confianza | Mifarma.es</title>\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta name="description" content="En la farmacia online MiFarma encontrar\xc3\xa1s todas las marcas y productos de parafarmacia al mejor precio. Env\xc3\xado 24h. \xc2\xa1Consulta todas las ofertas y promociones!" />\n<meta name="robots" content="INDEX,FOLLOW" />\n<link rel="icon" href="https://www.mifarma.es/media/favicon/default/favicon.png" type="i
# ...

# %%
soup = BeautifulSoup(response.content)

# %%
menu = soup.find_all(class_="level0 has-children")
menu
# Out:
# [<a class="level0 has-children" href="https://www.mifarma.es/cosmetica-y-belleza/">Cosmética y Belleza</a>,
#  <a class="level0 has-children" href="https://www.mifarma.es/nutricion/">Nutrición</a>,
#  <a class="level0 has-children" href="https://www.mifarma.es/herbolario/">Herbolario</a>,
#  <a class="level0 has-children" href="https://www.mifarma.es/infantil/">Infantil</a>,
#  <a class="level0 has-children" href="https://www.mifarma.es/higiene/">Higiene y Salud</a>,
#  <a class="level0 has-children" href="https://www.mifarma.es/optica/">Óptica</a>,
#  <a class="level0 has-children" href="https://www.mifarma.es/ortopedia/">Ortopedia</a>,
#  <a class="level0 has-children" href="https://www.mifarma.es/perfumeria/">Perfumeria</a>,
#  <a class="level0 has-children" href="https://www.mifarma.es/vida-intima/">Vida Íntima</a>,
#  <a class="level0 has-children" href="https://www.mifarma.es/regalos/">Regalos</a>]

# %%
len(menu)
# Out:
# 10

# %%
df_menu = pd.DataFrame(menu)
df_menu
# Out:
#                      0
# 0  Cosmética y Belleza
# 1            Nutrición
# 2           Herbolario
# 3             Infantil
# 4      Higiene y Salud
# 5               Óptica
# 6            Ortopedia
# 7           Perfumeria
# 8          Vida Íntima
# 9              Regalos

# %%
df_menu.to_csv("menú.csv")

# %% [markdown]
# ### Submenú

# %%
submenu = soup.find_all ('a', class_='level1')
submenu
# Out:
# [<a class="level1 has-children" href="https://www.mifarma.es/cosmetica-y-belleza/sol/">Sol</a>,
#  <a class="level1" href="https://www.mifarma.es/cosmetica-y-belleza/cabello/">Cabello</a>,
#  <a class="level1" href="https://www.mifarma.es/cosmetica-y-belleza/ojos/">Ojos</a>,
#  <a class="level1 has-children" href="https://www.mifarma.es/cosmetica-y-belleza/facial/">Facial</a>,
#  <a class="level1" href="https://www.mifarma.es/cosmetica-y-belleza/nutricosmeticos/">Nutricosméticos</a>,
#  <a class="level1" href="https://www.mifarma.es/cosmetica-y-belleza/hombres/">Hombres</a>,
#  <a class="level1" href="https://www.mifarma.es/cosmetica-y-belleza/cosmetica-natural/">Cosmetica Natural</a>,
#  <a class="level1" href="https://www.mifarma.es/cosmetica-y-belleza/cicatrices/">Cicatrices</a>,
#  <a class="level1 has-children" href="https://www.mifarma.es/cosmetica-y-belleza/accesorios-de-belleza/">Accesorios de Belleza</a>,
# ...

# %%
len(submenu)
# Out:
# 82

# %%
df_submenu = pd.DataFrame(submenu)
df_submenu
# Out:
#                   0
# 0               Sol
# 1           Cabello
# 2              Ojos
# 3            Facial
# 4   Nutricosméticos
# ..              ...
# 77   Falta de Deseo
# 78          Para Él
# 79        Para Ella
# 80            Bebés
# 81    Edad Avanzada
#
# [82 rows x 1 columns]

# %%
df_submenu.to_csv("submenú.csv")
